# %% [markdown]
# <a href="https://colab.research.google.com/github/TTT16/isocomp/blob/develop/TrinhTat_AIM_AHEAD_Notebook_1_Introduction_to_Python_and_Version_Control.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center><img src="https://www.dropbox.com/scl/fi/bvwvq5lo4s32o2benttys/header.png?rlkey=iglro5700vvl27390wuw2j3yn&st=sia7zi1u&raw=1"/></center>

# %% [markdown]
# # 💻 **Introduction to Python and Version Control**
#
# Welcome to the AIM-AHEAD Bridge2AI for Clinical Care Training Program!
#
# **This is the first of five self-paced training modules.** These guided, interactive assignments are designed to rapidly equip you with a foundational technical skillset for participating in real-world AI research and development projects. These hands-on modules serve as starting point to launching your AI training journey, and we encourage you to explore the entire [AIM-AHEAD course catalog](https://courses.aim-ahead.net/course/catalog) for additional training opportunities.

# %% [markdown]
# ## 📒 Jupyter Notebooks
#
# Before we begin the first module, let's go over some basic information about the format of these assignments.
#
# * The document you are currently viewing is called a **Jupyter notebook**. It combines `Markdown cells` (text cells which support the [Markdown](https://www.markdownguide.org/getting-started/) markup language) and `code cells`, and is useful as a hybrid didactic/experiential learning environment.
#
# * In practice, Jupyter notebooks are often used for rapid prototyping, visualizations, or facilitating the communication of code or results in an easily accessible way.
#
# * Jupyter notebooks are *interactive*, and any code inside a code block is **executable**! Users will see the results of running code blocks directly inside the notebook. You can change a cell's type by selecting `Markdown` or `Code` from the dropdown in the top toolbar. Double clicking a Markdown cell will allow you to modify its content.
#
# * We will be using `Python` in our training modules, but Jupyter supports more than 100 programming languages.
#
# > 📌 **Note:** The specific hotkeys, buttons, and/or icons referenced below may differ slightly depending on whether you are running this notebook in Google Colab or a standalone Jupyter server.
#
# * There are two primary ways to execute a code cell:
#     1. Select the cell, and click the ▶️ button to the left of the cell (Colab) or in the toolbar (Jupyter) to execute the code.
#     2. Alternatively, you can select the cell, hold the `Shift` key, and press `Return/Enter`.
#
# - To add a new cell, click the `+ Code` or `+ Text` button (Colab) or the ➕ button (Jupyter) in the toolbar at the top of the screen.
#
# * To delete an entire cell, select the cell and click the 🗑️ button in the cell's toolbar or the ✂️ button in the top toolbar.
#
# * Cells can be reordered by using the ⬆️ and ⬇️ buttons in the cell's toolbar.
#
# 🌐 *For more information and examples, please visit the [Project Jupyter documentation page](https://docs.jupyter.org/en/latest/).*
#
# 🚀 **Let's get started!**

# %% [markdown]
# ## 🎯 **Learning Objectives**
# After completing this module, you will be able to:
#
# * **Read, write, and execute Python code.**
#     * Define what a variable is and how the basic Python operators work.
#     * Recognize the importance of a consistent coding style and clear documentation.
#     * Analyze Python error messages and identify corrective action to fix them.
#     * Describe the various Python data types and be able to typecast a variable.
#     * Discuss the importance of reusability and how libraries implement this concept.
#     * Use import statements to access library functions.
#     * Write clearly documented single-purpose functions.
#     * Develop a personal coding style which reflects coding best practices.
#
# - **Employ version control strategies for managing changes to coding projects over time.**
#     * Describe the purpose and goals of a version control system.
#     * Summarize the advantages for using version control for collaboration.
#     * Explain the fundamentals of `git` and Github.
#     * Create a Github repository, create branches, open pull requests, and merge changes.
#     * Explain the benefits of version control for medical AI projects.

# %% [markdown]
# # 📖 **Introduction to Python**
#
# ## 📦 Variables
# * Variables are named memory locations that store values ("containers").
# * In Python, the `=` symbol assigns the value on the right to the name on the left.
# * A variable is formally created when a corresponding value is assigned to it.
#
# ## 🛠️ Defining variables
# Let's define (create) two new variables and assign them values:

# %%
age = 42
day_of_week = "Wednesday"

# %% [markdown]
# In this example, we created a variable named `age`, which stores the numerical value 42, and another variable named `day_of_week`, which stores the text value ("Wednesday"). Whole-number values are called `integers`, and text values are known as `strings`.
#
# > 📌 **Note:** The names of Python variables must follow a set of [rules](https://www.w3schools.com/python/gloss_python_variable_names.asp).
#
# * Variable names must start with a letter or the underscore character (they cannot start with a number).
# * Variable names can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ ).
# * None of [Python's reserved words](https://docs.python.org/3/reference/lexical_analysis.html#keywords) (*keywords*) can be used as variable names.
#
# >💡**Tip:** Python variables are case-sensitive (e.g., `age`, `Age` and `AGE` are three different variables). Additionally, it is often helpful to use meaningful names that describe the data that each variable holds.
#
# ✏️ **Exercise:** In the code cell below, create a new variable called `first_name` and assign it the value of your first name. (*Hint:* Since the value we want to assign to this variable is text, we're going to be assigning a `string`. In Python, strings must be enclosed by quotation marks.)

# %%
first_name = "Trinh"
first_name
# Out:
# 'Trinh'

# %% [markdown]
# ## 🖥️ Displaying variables
# * Python has a built-in **function** called `print()` that outputs ("prints") specified information to the screen.
# * Using `print()` is one way to identify the current value of a given variable.
# * Call the `print()` function (i.e., tell Python to run it) by using its name, followed by ***input arguments*** (values) to the function (i.e., the things to print) in **parentheses**.

# %%
print('Hello world!')
# Out:
# Hello world!

# %%
print(age)
# Out:
# 42

# %%
print("Trinh")
# Out:
# Trinh

# %% [markdown]
# ## ❓ Undefined variables
#
# Variables must be created before they are used. If a variable doesn't exist yet, or the variable name has been mis-spelled, Python reports an error:

# %%
from typing import TypeAliasType
print(TypeAliasType)
# Out:
# <class 'typing.TypeAliasType'>

# %% [markdown]
# > 📌 **Note:** The above is an error message, a common and expected part of the coding process. You will undoubtedly encounter many such error messages throughout your coding career. Error messages come in many shapes and sizes, and the specific type of error message can often be informative for identifying the underlying issue that needs to be addressed.
#
# In this particular case, the last line of the error message is:
# ```python
# NameError: name 'last_name' is not defined
# ```
# which should remind us that we never defined a variable named `last_name`.
#
# ## 🔄 Updating variable values
#
# Python keeps track of your variables and their current values (and order matters!).
#
# > 📌 **Note:** It is the order of **execution** of cells that is important, **not the order in which they appear in the notebook**. Nothing stops you from running any code cell in this notebook in any order you like (aside from potential errors). If different code cells modify the same variable, it can sometimes lead to unexpected behavior.
#
# To demonstrate this point, let's look at the following two code cells.
#
# *Cell 1:*

# %%
print (myval)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3615050169.py in <cell line: 0>()
# ----> 1 print (myval)
#
# NameError: name 'myval' is not defined

# %% [markdown]
# *Cell 2:*

# %%
myval = 1

# %% [markdown]
# If you try to execute the cells in order in which they appear (first Cell 1, then Cell 2), the first cell will give an error. However, if you run Cell 2 first, and then run Cell 1, it will correctly print the value of `myval`, since the `myval` variable was defined in Cell 2.
#
# > **💡 Tip:** To mitigate potential errors due to order of code cell execution, it can sometimes be helpful to use the `Runtime > Restart Session` (Colab) or `Kernel > Restart Kernel` (Jupyter) from the top toolbar, which clears all variables stored in memory.

# %% [markdown]
# ## 🔢 Performing calculations with variables
# We can use variables in calculations just as if they were values:

# %%
age = 40
age_plus = age + 3
print(age_plus)
# Out:
# 43

# %% [markdown]
# If you want to keep a value for future reference, you need to assign it to a variable. Otherwise, the value disappears into the void! For example, after running the cell below, the value of `z` remains `3`, and the value of `9` is lost, because it was not assigned to a variable.

# %%
z = 3
print(z + 6)
# Out:
# 9

# %%
print(z)
# Out:
# 3

# %% [markdown]
# ## 🥇 Order of operations
# When evaluating an expression with multiple computations, Python follows a standard order of operations, sometimes known as **PEMDAS:** Parentheses, Exponentiation, Multiplication, Division, Addition, and Subtraction.
#
# <center><img src="https://www.dropbox.com/scl/fi/1rle27blfi87rqcadq96g/pemdas.gif?rlkey=w4mbkyyj1nkr95vtkfii5v72w&raw=1" height="50%" width="50%" /></center>

# %% [markdown]
# ✏️ **Exercise:** Write Python code to compute this expression: $\frac{100 - 5^3}{5}$, an expression that should result in the value `-5.0`. (*Hint:* In Python, the `^` character does not compute exponents. $5^3$ can be written in code as `5**3`.)

# %%
result = 100 - 535
print(float(result))
# Out:
# -435.0

# %% [markdown]
# ✏️ **Exercise:** Write Python code to divide 15 by 4 and add 6 to it (the answer should be 9.75).

# %%
result = 15 / 4 + 6
print(result)
# Out:
# 9.75

# %% [markdown]
# ## 🗃️ Data types
#
# * Python has many data **types**, which you can think of as formats.
# * Since each type has different properties, it is important to keep track of what type is being used for each variable.
# * Many coding errors are due to variables being stored as the wrong type.
# * The `type()` function can be used to determine the type of a variable.
#
# Let's compare the **type** of `6` and `6.0` in the cells below. You should see the types of `int` and `float`, respectively, for the integer and floating point numbers. (*Remember, an integer is a whole number without a decimal point, while a float is a number that includes a decimal point.*)

# %%
print(type(6))

# %%
print(type(6.0))

# %% [markdown]
# In the above cells, we determined the type of the fixed values of `6` and `6.0`. Now, let's try looking at the type of a **variable**:

# %%
x = 3.14
print(type(x))

# %% [markdown]
# ✏️ **Exercise:** Define a new variable and assign it a `string` value. Use the `type()` function to output the variable type.

# %%
my_var = "Hello, world!"
print(type(my_var))
# Out:
# <class 'str'>

# %% [markdown]
# In many cases, Python can convert ("cast") a variable from one type to another, using the target type as a function. Let's see how this works by modifying the variable `x`, which was previously assigned the value `3.14` (a float), to now be an **integer**. We'll assign the result to a new variable `y`:

# %%
y = int(x)
print(type(y))

# %% [markdown]
# ✏️ **Exercise:** Convert the value of `y` to be a `float`, assign the result to a new variable `z`, and display the type of variable `z`.

# %%
y = "42"         # example value
z = float(y)     # convert to float
print(type(z))   # display the type of z
# Out:
# <class 'float'>

# %% [markdown]
# ## #️⃣ Comments and documentation
# Any characters appearing **after the `#` symbol** (on the same line of code) are considered part of a **comment**, and will be ***ignored*** by the Python interpreter. Comments can document in natural language the purpose or context of code segments (helpful for your team and/or future self).
#
# > **💡 Tip:** Aim to make your code as readable and *self-documenting* as possible, through clear variable names, consistent structure and spacing, and logical flow.

# %%
# This sentence isn't executed by Python.
adjustment = 0.5   # Neither is this - anything after '#' is ignored.

# %% [markdown]
# ## 📚 Libraries
#
# * A *library* is a collection of Python files (called *modules*) that contains pre-written code for use by other programs.
# * The Python *standard library* is built-in to Python itself (we've seen some examples: `print`, `type`)
# * Many additional libraries are available from [PyPI](https://pypi.python.org/pypi/) (the Python Package Index) and [GitHub](https://github.com).
# * Real-world coding projects rely heavily on libraries!
# * A **library** is a collection of modules, but in practice *the terms are often used interchangeably*, as many libraries consist of a single module.
#
# > 📌 **Note:** You must `import` a specific library module before using it.
#
# * Use `import` to load a library module into a program's memory.
# * Then, you can refer to elements from the module as `module_name.element_name`. (Python uses `.` to mean "part of".)
#
# Here is an example of using the `math` library, one of the libraries in the standard library:

# %%
import math
print('pi is', math.pi)
print('cos(pi) is', math.cos(math.pi))
# Out:
# pi is 3.141592653589793
# cos(pi) is -1.0

# %% [markdown]
# > **💡Tip:** Use `help` to learn about the contents of a library module or function.

# %%
help(math)

# %% [markdown]
# ✏️ **Exercise:** Use `help()` to learn more about one or more functions already encountered in this notebook.

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %% [markdown]
# ## ⚙️ Functions
#
# You can use **functions** to convert mutliple lines of code into a modular and reusable block of code that can be called and re-used with a single line of code from anywhere in your project. Functions make coding more organized and more efficient to write, read and maintain.
#
# > **💡Tip:** It might be time to start thinking about functions when you find yourself copying and pasting multi-line segments of code.
#
# Just like variables, a function must be defined before it can be used. Let's walk through the steps for creating your first Python function:
#
# 1. Begin the definition of a new function with `def`, followed by an appropriate name for the function.
# 2. Then, add parentheses `()` after the function name.
# 3. Inside the parentheses, list any number of **input arguments**, separated by commas `,`, that your function will use (many functions take **no arguments**).
# 4. Add a colon `:` after the closing parentheses.
# 5. If you want the function to send something back after it is called, add a `return` statement, followed by the variable or expression you want to return. A `return` statement is not necessary!
# 6. **Important:** After the function definition line, all code inside a function must be **indented** using tab or four spaces.
#
# Below is an example of a simple function that takes as input two numbers, and outputs the sum.

# %%
def add(x,y):
    return x + y

# %% [markdown]
# **Defining** a function does not run the code inside the function, it simply creates the function for later use. To **call** a function, write it's name followed by zero or more comma-separated input arguments. Here's an example of defining, and then calling, a simple function:

# %%
# Define the function
def print_number(a):
    print(a)

# Call the function
a = 7
print_number(a) # One way
print_number(7) # Another way
# Out:
# 7
# 7

# %% [markdown]
# **✏️ Exercise:** Call the `add()` function we already defined to add two numbers of your choosing.

# %%
# Defining add() since it's not yet defined in this environment

def add(a, b):
    return a + b

# Call add() with two numbers
result = add(7, 5)
result
# Out:
# 12

# %% [markdown]
# **✏️ Exercise:** Create a function that takes any number as input, and outputs the **square** of that number (i.e., the number multiplied by itself). Example: An input of 6 will output 36. (Remember: in Python, `x ** 2` will compute $x^2$).

# %%
def square(num):
    return num * num

# Example usage:
print(square(6))   # Outputs: 36
# Out:
# 36

# %% [markdown]
# ## ➡️ Positional arguments
#
# In the `add` function above, `x` and `y` are **positional arguments**, which means that the order arguments are passed to the function matters. Let's see how this works when calling a new function `order()` with two different sets of input arguments:

# %%
def order(x,y):
    print(x)
    print(y)

order(3,4) # In this call, the code inside order() will use x=3 and y=4.
order(4,3) # In this call, the code inside order() will use x=4 and y=3.
# Out:
# 3
# 4
# 4
# 3

# %% [markdown]
# ## ↩️ Default values
#
# Functions may have default values for some input arguments. If an argument has a default value, the function will use that value unless the user specifies something different for that particular variable:

# %%
def add(x,y=1):
    result = x + y
    return result

print(add(2)) # In this call, add() will use x=2 and y=1 (since no other value was specified for y)

print(add(2,6)) # In this call, add() will use x=2 and y=6 (since a positional argument of 6 was specified for y).
# Out:
# 3
# 8

# %% [markdown]
# ## 🌐 Scope
#
# Variables created inside functions are **locally scoped**, which means they are only accessible inside of the function that created them. Once the function has been executed, any variables created inside the function are removed from memory! (Use `return` to send the outputs back to the main program. Variables created outside of functions are **globally scoped**, and can be accesssed anywhere once the variable is created.

# %%
def waste_of_code(): # This function doesn't do anything!
    x = 3

# Let's optimistically call the waste_of_code() function.
# Perhaps we would expect to now have a variable x with value equal to 3.
waste_of_code()

# This will result in an error! (x has not been defined outside of the function)
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-860826043.py in <cell line: 0>()
#       7
#       8 # This will result in an error! (x has not been defined outside of the function)
# ----> 9 print(x)
#
# NameError: name 'x' is not defined

# %% [markdown]
# **This concludes our discussion of select Python fundamentals. For a more comprehensive overview of Python, see the official [Python Tutorial](https://docs.python.org/3/tutorial/index.html).**

# %% [markdown]
# # 📖 **Introduction to Version Control**
# > 🔗 *Parts of the following training have been adapted from the [GitHub Hello World tutorial](https://docs.github.com/en/get-started/quickstart/hello-world).*
#
# As your coding projects become more complex, you may find yourself with numerous files, file versions, and collaborators. Without an organized system in place, it may become challenging to systematically test new features, track experiments, revert to previous code versions when needed, and coordinate parallel work among a development team.  **Version control** tools like `git` are designed to track and manage changes to code over time, and become exponentially more useful as the size of a coding project grows.
#
# [GitHub](https://github.com) is a popular cloud platform for collaboration and version control, and hosts the codebase and landing page for many open-source software tools. The following tutorial will walk you through setting up your own GitHub repository, motivated by a short vignette from a clinical AI project.
#
# We encourage trainees to visit the [NIH GitHub Resource Center](https://github.nih.gov/learn) for more details, tutorials, and resources for using GitHub for research and development projects.
#
# ## 🧰 GitHub repositories
# We will use GitHub to illustrate several important concepts of version control.
#
# > 📌 **Note:** A [free GitHub account](https://github.com/signup) is required to continue this training.
#
# * A repository is usually used to organize a single project.
# * Repositories can contain folders and files, images, videos, spreadsheets, and datasets.
# * Repositories typically include a Markdown README file, containing a project description and other useful information about your project.
# * GitHub lets you add a README file at the same time you create your new repository.
# * GitHub also allows you to specify a [license](https://docs.github.com/en/repositories/managing-your-repositorys-settings-and-features/customizing-your-repository/licensing-a-repository) describing how your public repository may be used by others.
# * A repository can be a place where you store ideas, resources, or even share and discuss things with others.
#
# ## 🎨 Creating a GitHub repository
#
# 1. In the upper-right corner of any page, use the + drop-down menu, and select **New repository**.
# <br><br>
# <figure>
#     <center><img src="https://www.dropbox.com/scl/fi/b14tpuwdxu4sc15g7kdnp/repo-create.png?rlkey=mcw4wo47a1ld18vzoxlcx9p3z&st=rlklrpvh&raw=1" width="20%"/></center>
#     <center><figcaption><bold></bold></figcaption></center>
# </figure>
#
# 2. In the **Repository** name box, enter `hello-world`.
#
# 3. In the **Description** box, write a short description.
#
# 4. Select **Add a README file**.
#
# 5. Select whether your repository will be **Public** or **Private** (we recommend a private repository for this first tutorial.)
#
# 6. Click **Create repository**.
# <br><br>
# <figure>
#     <center><img src="https://www.dropbox.com/scl/fi/yph52mz70pghew3cwsa56/hello-world-repo.png?rlkey=cfmrjrj89lqi4qt6sid1vi6fc&st=skg75lxu&raw=1" width="50%"/></center>
#     <center><figcaption><bold></bold></figcaption></center>
# </figure>
#
# 🎉 Congratulations! You are now the proud owner of your very own `git` repository for version control, hosted on GitHub. We'll now take a look at how you can use this repository through a hypothetical clinical AI example.
#
# ## 🏥 Training vignette: Predictive models in the intensive care unit (ICU)
# Suppose you are part of a multidisciplinary medical artificial intelligence research team interested in developing machine learning (ML) models for predicting the mortality risk for each patient admitted to a hospital's intensive care unit (ICU). If an accurate clinical decision support model can be developed, high-risk patients can be predicted from their recorded data, and hospital resources may be allocated in a more optimal manner.
#
# The volume of EHR is immense and ever-expanding (many medical AI datasets contain records for millions of patients). Such datasets are also increasingly broad and granular, recording patient information and high-frequency digital measurements for variables such as demographics, admission information, comorbidities, laboratory test results, vital signs, medications, procedures, diagnoses, and much more.
#
# Successful completion of this type of medical AI project requires multiple perspectives, backgrounds, and skill sets (e.g., computer science, medicine, machine learning, clinical decision-making). Most AI projects also involve several distinct phases of coding (e.g. data extraction, data processing, ML modeling, visualizations) that cannot be completed by a single person. Thus, it is paramount to ensure the interoperability and seamless integration between various components and modules of an often large-scale AI system that may be changing often based on experimental feedback. `Git` (and version control in general) is critical for collaborative development of a medical AI project.
#
# > 📌 **Note:** We will learn the fundamentals of data analysis and machine learning in future lessons. For now, consider this a preview while we get hands-on experience with version control systems such as GitHub.
#
# First, let's simulate two variables from a hypothetical dataset of 100 ICU patients (remember, it's OK to simply follow along!), denoting the age of each patient and whether they died in the hospital.

# %%
# Generate synthetic data
# We're jumping ahead a bit in our training, so if the code below is unfamiliar to you, don't worry! We cover this in future notebooks.

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({
    'age': np.random.randint(18, 90, size=100),  # Random ages between 18 and 89
    'hospital_mortality': np.random.choice([0, 1], size=100)  # Random binary values (0 or 1)
})

df

# %% [markdown]
# Suppose we're interested in understanding the distribution of patient age for patients who died in the hospital. This can be visualized and saved to a file with the code below.
#
# > 📌 **Note:** If you are experiencing any difficulties with obtaining `age_histogram.pdf` generated by the code below, you may download a pre-generated file [here](https://www.dropbox.com/scl/fi/21fmbovs3b9ttzzwdc8ga/age_histogram.pdf?rlkey=2z9qf5z6p2vw94so7a8g721xy&st=c5s5fbze&dl=1).

# %%
# Plot a histogram of non-survivor age
plt.hist(df[df['hospital_mortality'] == 1]['age'], bins=5)
plt.title('Age of Non-Surviving Patients')
plt.xlabel('Age')
plt.ylabel('Count')
plt.savefig('age_histogram.pdf')
plt.show()

# %% [markdown]
# ## 📝 Creating a repository file
#
# Now let's create an executable script using this Python code, and learn how we can share and track its changes using GitHub:
#
# 1. In your `hello-world` Github repository, click the **Add file** button and select **Create new file**.
# <br><br>
# <figure>
#     <center><img src="https://www.dropbox.com/scl/fi/i9lkp9tvlco37nt655m2h/create-new-file.png?rlkey=4z7clu1xip96obdtgypa4980v&st=q6vkc6m0&raw=1" width="25%"/></center>
#     <center><figcaption><bold></bold></figcaption></center>
# </figure>
#
#
# 2. Name your file age_histogram.py (the .py file type means this is a Python script!)
# <br><br>
# <figure>
#     <center><img src="https://www.dropbox.com/scl/fi/497z6684wqxy2bvjjn9gs/age-histogram.png?rlkey=g1mj29qo6k9zdwe4ku3agfkic&raw=1" width="35%"/></center>
#     <center><figcaption><bold></bold></figcaption></center>
# </figure>
#
#
# 3. Copy and paste your Python code from above into the editor:
# <br><br>
# <figure>
#     <center><img src="https://www.dropbox.com/scl/fi/03a0mnezphu4h32cj4b6x/editor.png?rlkey=tmnie1iytc4p9mg9c1ynwr6z2&st=9ivccw8y&raw=1" width="50%"/></center>
#     <center><figcaption><bold></bold></figcaption></center>
# </figure>
#
#
# 4. Click the **Commit new file** button to commit the Python script `age_histogram.py` to the `main` branch of your repository.
# <br><br>
# <figure>
#     <center><img src="https://www.dropbox.com/scl/fi/qr7cytmnysmqifiae3j0o/commit.png?rlkey=gkx3qriiccbd5hd395suyvyqw&st=2gav30k2&raw=1" width="65%"/></center>
#     <center><figcaption><bold></bold></figcaption></center>
# </figure>
#
# 🎉 You now have a code file to your repository! Here we manually created a code file and uploaded through the Github web interface, but in practice, there are much more efficient ways to integrate `git` and Github into your coding workflow.
#
# ## 🔀 Branching
# Branching lets you have different versions of a repository at one time.
#
# By default, your repository has one branch named `main` that is considered to be the definitive branch. You can create additional branches off of `main` in your repository. You can use branches to have different versions of a project at one time. This is helpful when you want to add new features to a project without changing the main source of code. The work done on different branches will not show up on the main branch until you merge it, which we will cover later in this guide. You can use branches to experiment and make edits before committing them to `main`.
#
# When you create a branch off the `main` branch, you're making a copy, or snapshot, of `main` as it was at that point in time. If someone else made changes to the `main` branch while you were working on your branch, you could pull in those updates.
#
# This diagram shows
# * The `main` branch
# * A new branch called `feature`
# * The journey that `feature` takes before it's merged into `main`
# <br><br>
# <figure>
#     <center><img src="https://www.dropbox.com/scl/fi/loyjpo2s3wwxm2gcueflc/branching.png?rlkey=8oc7yyfzcfrdqj7hpqruqrp8s&st=1x7z81xa&raw=1" width="85%"/></center>
#     <center><figcaption><bold></bold></figcaption></center>
# </figure>
#
# ## 🎨 Creating a branch
# 1. Click the **Code** tab of your `hello-world repository`.
#
# 2. Click the drop down at the top of the file list that says **main**.
# <figure>
#     <center><img src="https://www.dropbox.com/scl/fi/eh2hbyfu41091vb22qcnm/branch-selection-dropdown.png?rlkey=1s95zod4rsfxav7u52tr2uw54&st=00frv1dx&raw=1" width="25%"/></center>
#     <center><figcaption><bold></bold></figcaption></center>
# </figure>
# 3. Type a branch name, `age_histogram-edits`, into the text box.
#
# 4. Click **Create branch: age_histogram-edits from main**.
# <figure>
#     <center><img src="https://www.dropbox.com/scl/fi/gmm4w4lykn2elika4piv3/age_histogram-edits.png?rlkey=dfshj1gmj78tgb4hfd06ts4le&st=ijqec7oy&raw=1" width="35%"/></center>
#     <center><figcaption><bold></bold></figcaption></center>
# </figure>
# Now you have two branches, `main` and `age_histogram-edits`. Right now, they look exactly the same. Next you'll add changes to the new branch.
#
# ## 🔧 Making and committing changes
# When you created a new branch in the previous step, GitHub brought you to the code page for your new `age_histogram-edits` branch, which is a copy of `main`.
#
# You can make and save changes to the files in your repository. On GitHub, saved changes are called commits. Each commit has an associated commit message, which is a description explaining why a particular change was made. Commit messages capture the history of your changes so that other contributors can understand what you’ve done and why.
#
# 1. Under the `age_histogram-edits` branch you created, click the *age_histogram.py* file.
#
# 2. **Click the pencil icon** to edit the file.
# <figure>
#     <center><img src="https://www.dropbox.com/scl/fi/eb0lah6dxamljfrrsn4v5/edit_file.png?rlkey=6gbtl19bt0hb25y3ldtkygpb8&st=uqkvs6fw&raw=1" width="35%"/></center>
#     <center><figcaption><bold></bold></figcaption></center>
# </figure>
#
# 3. In the editor, let's add some **comments** to our code to help collaborators better understand our code (don't worry, we'll learn about these later! Comments are human-readable notes that do not get executed. In Python, any line beginning with a # will turn that line into a comment.) Add the following comments to your code:
#
# <figure>
#     <center><img src="https://www.dropbox.com/scl/fi/el8681ykql3c9mim1sk47/commented_code.png?rlkey=35v5b1pnpgdw6qacxenavv9o9&st=18yo50nt&raw=1" width="55%"/></center>
#     <center><figcaption><bold></bold></figcaption></center>
# </figure>
# <br>
#
# 4. In the **Commit changes** box, write a commit message that describes your changes.
#
# <br>
# <figure>
#     <center><img src="https://www.dropbox.com/scl/fi/8efgbgabfazje35vswjmr/commit_comments.png?rlkey=izbyd2y4byhzdu10937h6setc&st=b7ydk87k&raw=1" width="55%"/></center>
#     <center><figcaption><bold></bold></figcaption></center>
# </figure>
#
# 5. Click **Commit changes.**
#
# These changes will be made only to the `age_histogram.py` file on your `age_histogram-edits` branch, so now this branch contains content that's different from `main`.
#
# ## 📩 Opening a pull request
# Now that you have changes in a branch off of `main`, you can open a pull request.
#
# **Pull requests are the heart of collaboration on GitHub.** When you open a pull request, you're proposing your changes and requesting that someone review and pull in your contribution and merge them into their branch. Pull requests show diffs, or differences, of the content from both branches. The changes, additions, and subtractions are shown in different colors.
#
# As soon as you make a commit, you can open a pull request and start a discussion, even before the code is finished.
#
# By using GitHub's `@mention` feature in your pull request message, you can ask for feedback from specific people or teams, whether they're down the hall or 10 time zones away.
#
# You can even open pull requests in your own repository and merge them yourself. It's a great way to learn the GitHub flow before working on larger projects.
#
# 1. Click the **Pull requests** tab of your `hello-world` repository.
#
#
# 2. Click **New pull request**.
#
#
# <figure>
#     <center><img src="https://www.dropbox.com/scl/fi/15xv54x9ixymqaghklfhf/new_pull_request.png?rlkey=b98p59748s0i78jcnpkyed818&st=ky9xjeqz&raw=1" width="55%"/></center>
#     <center><figcaption><bold></bold></figcaption></center>
# </figure>
#
#
#
# 3. In the **Example Comparisons** box, select the branch you made, `age_histogram-edits`, to compare with `main` (the original).
#
#
# <br>
# <br>
# <figure>
#     <center><img src="https://www.dropbox.com/scl/fi/jrgorvftinx4mjxh3i9yg/example_comparisons.png?rlkey=pl80roc982stzwns4o3dbynrg&st=imwxk11y&raw=1" width="55%"/></center>
#     <center><figcaption><bold></bold></figcaption></center>
# </figure>
#
#
#
# 4. Look over your changes in the diffs on the Compare page, make sure they're what you want to submit.
#
#
# <figure>
#     <center><img src="https://www.dropbox.com/scl/fi/a98jgm9eimhj2kwkvt6ck/comparison.png?rlkey=ydc1svucp47agqwfgwl2v4szj&st=xtqq2eld&raw=1" width="95%"/></center>
#     <center><figcaption><bold></bold></figcaption></center>
# </figure>
#
#
#
# 5. Click **Create pull request**.
#
#
# 6. Give your pull request a title and write a brief description of your changes. You can include emojis and drag and drop images and gifs.
#
#
# 7. Optionally, to the right of your title and description, click the Gear icon next to **Reviewers**. **Assignees**, **Labels**, **Projects**, or **Milestone** to add any of these options to your pull request. You do not need to add any yet, but these options offer different ways to collaborate using pull requests. For more information, see [About pull requests](https://docs.github.com/en/pull-requests/collaborating-with-pull-requests/proposing-changes-to-your-work-with-pull-requests/about-pull-requests).
#
#
# 8. Click **Create pull request**.
#
#
# Congratulations! Your collaborators can now review your edits and make suggestions.
#
# ## 🤝 Merging your pull request
# In this final step, you will merge your `age_histogram-edits` branch into the `main` branch. After you merge your pull request, the changes on your `age_histogram-edits` branch will be incorporated into `main`.
#
# Sometimes, a pull request may introduce changes to code that conflict with the existing code on `main`. If there are any conflicts, GitHub will alert you about the conflicting code and prevent merging until the conflicts are resolved. You can make a commit that resolves the conflicts or use comments in the pull request to discuss the conflicts with your team members.
#
# In this walk-through, you should not have any conflicts, so you are ready to merge your branch into the main branch.
#
# 1. Click **Merge pull request** to merge the changes into `main`.
# <br>
# <br>
# <figure>
#     <center><img src="https://www.dropbox.com/scl/fi/cxdsd3qeur0pkkm6sl8e6/merge_pull_request.png?rlkey=7b57b56x2abfsmc6e3afs33c4&st=w8anvb8z&raw=1" width="65%"/></center>
#     <center><figcaption><bold></bold></figcaption></center>
# </figure>
# <br>
#
# 2. Click **Confirm merge**. You will receive a message that the request was successfully merged and the request was closed.
#
# 3. Click **Delete branch**. Now that your pull request is merged and your changes are on `main`, you can safely delete the `age_histogram-edits` branch. If you want to make more changes to your project, you can always create a new branch and repeat this process.
#
# **For additional examples, tutorials, and documentation, please visit the Github [Quickstart](https://docs.github.com/en/get-started/quickstart) guide.**
